# %% [markdown]
# <a href="https://colab.research.google.com/github/NidhiChaurasia/PythonProjects/blob/main/Web_Scraping_from_Static_Website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install beautifulsoup4  #this library enables web-scraping using python

# %%
! pip install requests   #to extract data from any website we have to send request so we install requests library in python

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ##Loading Website to extract essential data from it -

# %%
try:
    
    page=requests.get('https://www.cricbuzz.com/')  #inside the page object we store the response of cricbuzz site

except Exception as e:
  error_type, error_obj, error_info = sys.exc_info()
  print('ERROR FOR LINK:',url)
  print(error_type,'Line:',error_info.tb_lineno)

time.sleep(2)
soup=BeautifulSoup(page.text,'html.parser')  #obj soup stores html parsed into text
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})  #obj links stores the extracted data from the website under the div class cb-nws-intr that holds
                                                         # the headlines of the news on that site

# %%
page #we got the response from the site cricbuzz.The HTTP 200 OK success status response code indicates that the request has succeeded.
     # A 200 response is cacheable by default.
# Out:
# <Response [200]>

# %% [markdown]
# ##HTML Parsing into text form

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links
# Out:
# [<div class="cb-nws-intr">A near-perfect first day of the series gives India a foothold to launch a victory push from</div>,
#  <div class="cb-nws-intr">Mustafizur also played his part with a three-for</div>,
#  <div class="cb-nws-intr">While Anderson had the better of Kohli in 2014, the Indian skipper did come out on top in 2018</div>,
#  <div class="cb-nws-intr">Unlike his proud record in Australia, Pujara's stats in very different conditions of England take a big dip</div>,
#  <div class="cb-nws-intr">This will be New Zealand first tour to the Asian nation in 18 years</div>,
#  <div class="cb-nws-intr">Thabang Moroe tried to use the platform to polish his tarnished reputation while Prince looked, critically, at the realities of cricket as they have been shaped by the wider realities beyond</div>,
#  <div class="cb-nws-intr">Recently two CPL franchises, having owners who also had IPL teams were renamed to be more in tune with the brand</div>,
# ...

# %% [markdown]
# ##Extracted News Headers from the Cricbuzz site which is a legal task in public relations and can be further used as raw data to create a dataset or project-purpose usability.

# %%
for i in links:
  print(i.text)  #processing data into structured format
  print("\n")
# Out:
# A near-perfect first day of the series gives India a foothold to launch a victory push from
#
#
# Mustafizur also played his part with a three-for
#
#
# While Anderson had the better of Kohli in 2014, the Indian skipper did come out on top in 2018
#
#
# Unlike his proud record in Australia, Pujara's stats in very different conditions of England take a big dip
#
#
# This will be New Zealand first tour to the Asian nation in 18 years
#
#
# Thabang Moroe tried to use the platform to polish his tarnished reputation while Prince looked, critically, at the realities of cricket as they have been shaped by the wider realities beyond
#
#
# Recently two CPL franchises, having owners who also had IPL teams were renamed to be more in tune with the brand
#
#
# Birmingham chase down 174 with six balls to spare in a run-fest
#
#
# With the rescheduling of England's tour Bangladesh, the door has opened for the duo to take part in IPL
#
#
# ...
